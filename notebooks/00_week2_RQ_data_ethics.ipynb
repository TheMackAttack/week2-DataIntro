# %% [markdown]
# # Research Question, Dataset, and Ethics Check
#
# Use this notebook to document three things for your proposed research project:
#
# 1. Your research question
# 2. The dataset you plan to use
# 3. The ethical aspects you have considered
#
# > Do not load or analyse the data in this notebook. Choose a dataset, provide a reliable reference link, explain why you chose it, and answer the ethics questions using the dataset documentation and any relevant research literature. If a question is not applicable, write N/A and explain why.
#
# ## 1. Research Question
# Title : The Perfect Shot? Predicting NBA shot success using machine learning.
#
# - **Main research question:** Which combinations of shot distance, nearest-defender distance, number of dribbles, touch time and time remaining on the shot clock are associated with the highest probability of making an NBA shot.
# - **Why is this question interesting or important?** [Understanding which shot conditions are associated with a higher chance of scoring can help players and coaches make more informaed shot-selection decisions. Using machine learning allows us to examine how these factors work together rather than considering each one in isolation.]
# - **Who might use or care about the answer?** [This question may be relevant to basketball players, scouts or coaches. Determining the optimum shot selection allows players to increase their scoring outcomes, improving shot selection may lead to increased success.]
# - **Possible sub-questions:** [1. How does distance from the basket relate to the probability of making a shot. 2. Hos does the nearest defenders distance relate to shot success, and does this relationship vary with shot distance. 3. Do away games skew results? are players less likely to score in general when playing an away game and if so what implication would this have on our study. ]
#
# ## 2. Dataset Reference
#
# - **Dataset name:** [NBA Shot Logs, Version 1]
# - **Source link:** [NBA Shot Logs on Kaggle. ( https://www.kaggle.com/datasets/dansbecker/nba-shot-logs)]
# - **Date accessed:** [2026-09-21]
# - **Who published or collected it?** [Published on Kaggle by Dan Becker, whose account is dansbecker and display name is "DanB". The uploader states that the data was scraped from the NBA's rest API]
# - **Why did you choose this dataset?** [We have identified multiple shot log data sets, however none as comprehensive as this one. It contains individual shot attempts with their outcomes and contextual variables.]
# - **Evidence or notes:** [The kaggle documentation identifies the sources as the NBA's REST API and describes coverage of shots from the 2014-2015 season. It provides a CSV containing 21 columns. The license is listed as "Unknown", and the collection and processing methods are not fully documented; these limitations will be discussed further in the ethics checklist.]

# %% [markdown]
# ## Research Questions and Answers
#
# For every answer, distinguish between **known evidence**, **reasonable interpretation**, and **unknown information to investigate**.
#
# ### 1. Where did the data come from?
#
# **Answer:** [Known Evidence : The dataset, NBA Shot Logs, is published on Kaggle under Dan Beckers account, dansbecker, displayed as "DanB". The dataset desciption states that it was scraped from the NBA's REST API-- an online service providing NBA statistics. The NBA's tracking system at the time was STATS LLC's SportVU, which used camers and software to measure player and ball movements. Unknown information to investigate: The exact scraping date, extraction code and any changes made before uploading are not established by the data set description. The exact ownership and reuse rights also require clarification, Kaggle lists the license as unknown.]
#
# ### 2. Why was it originally collected?
#
# **Answer:** [Known Evidence : The NBA and STATS collected tracking information to analuse player and team performance and provide ricker statistics for fans. The NBA also identifies scouting player development and training as uses of SportVu data. Reasonable interpretation: Our research reuses these records for educational research into shooting conditions and shot success. This is closely related to the original performance analysis purpose. Unkown information: The documentation ]
#
# ### 3. Who is represented?
#
# **Answer:** [Known: Published research describes the data set as containing 128,069 two and three point shots, covering 28 October 2014 to 4 March 2015. Reasonable interpretation: The population represented is professional men's NBA basketball players whose attempts were included alongside their nearest defender.Unkown: information to investigate : We need to confirm the downloaded files date, number of unique players, team coverage and completeness within the reported period.]
#
# ### 4. Who might be missing?
#
# **Answer:** [Known Evidence: The datat set does not cover the complete season and records 2-3 pt attempts and not free throws. Reasonable interpretation: The data set only contains mens professional basketball and does not include WNBA, youth players or amateur players. Unknown : we need to investigate whether particular players, games or shooting situations are disproportionally missing and whether removing incomplete records would make this imbalance worse.]
#
# ### 5. What personal or sensitive information does it contain, explicitly or implicitly?
#
# **Answer:** [Known : The documented columns include shooter and nearest-defender names and player ID's. The data set is therefore not annonymous. However no sensitive information is being handled. Interpretation : The data set does not include personal or sensitive information, however performance information may be professionally sensitive if used to judge a players ability or value. Unknown : We should investigate whether downloaded files match the documented columns, we intend to select over 30 shots at random and retrieve the games highlights to confirm all data is accurately recorded.]
#
# ### 6. What could your analysis reveal that was not obvious in the original data?
#
# **Answer:** [Known : The dataset could allow us to determine the optimum shot selection. Interpretation : Machine learning could reveal interactions, for example whether the relationship between defender distance and scoring probability varies with shot distance. Unknown: The exact position on the court. A person may be more likely to score at the top of the arc rather than at the corner of the arc, this is a core piece of data that we are missing.]
#
# ### 7. Who could benefit from your findings?
#
# **Answer:** [Known : Our data could help players and coaches optimize shot selection. Interpretation: Optimizing shot selection will drive more succesful outcomes and increase win percentage. Unknown: Practical benefits depend on model accuracy. Whether following any strategy improves performance would require further testing. ]
#
# ### 8. Who could be harmed or misrepresented?
#
# **Answer:** [Known : The dataset represent NBA professional athletes, the design of the model does not inted to explicitly target any player. Interpretation : All infromation possessed in the data set is publicly available, therefore the model does not target any individual or groups. Unknown: Potential we could unknowningly target players via labelling them bad shooters. ]
